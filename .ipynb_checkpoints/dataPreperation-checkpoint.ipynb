# %%
import pandas as pd
import numpy as np

import pycountry
# visualisation
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)
from scipy.stats import norm
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display

import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Wholesale Price Index (Excl VAT) for Building and Construction Materials

# %%
# construction market indices
df_wpm=pd.read_csv('WPM28.20230512223723.csv')
df_wpm.head()
# Out:
#   STATISTIC                                    Statistic Label  TLIST(M1)  \
# 0  WPM28C01  Wholesale Price Index (Excl VAT) for Building ...     201501
# 1  WPM28C01  Wholesale Price Index (Excl VAT) for Building ...     201501
# 2  WPM28C01  Wholesale Price Index (Excl VAT) for Building ...     201501
# 3  WPM28C01  Wholesale Price Index (Excl VAT) for Building ...     201501
# 4  WPM28C01  Wholesale Price Index (Excl VAT) for Building ...     201501
#
#           Month C01409V03262        Type of Material           UNIT  VALUE
# 0  2015 January            -               Materials  Base 2015=100   99.2
# 1  2015 January          601  Stone, sand and gravel  Base 2015=100   95.7
# 2  2015 January        60161         Sand and gravel  Base 2015=100   98.0
# 3  2015 January        60162                   Stone  Base 2015=100   95.3
# 4  2015 January          611                  Cement  Base 2015=100  100.0

# %%
df_wpm["Type of Material"].value_counts()
# Out:
# Materials                                               297
# Stone, sand and gravel                                  297
# Bituminous macadam, asphalt and bituminous emulsions    297
# Bituminous macadam and asphalt                          297
# Bituminous emulsions                                    297
# Electrical fittings                                     297
# Lighting equipment                                      297
# Protection and communication equipment                  297
# All other materials                                     297
# Plumbing materials including sanitary ware              297
# HVAC (heating and ventilation equipment)                297
# Insulating materials                                    297
# Pipes and fittings                                      297
# PVC pipes and fittings                                  297
# Copper pipes and fittings                               297
# Plaster                                                 297
# Paints, oils and varnishes                              297
# Glass                                                   297
# All other metal fittings                                297
# Wooden windows and doors                                297
# Other treated timber                                    297
# Machined, treated engineered timber                     297
# Precast concrete                                        297
# Sand and gravel                                         297
# Stone                                                   297
# Cement                                                  297
# Ready mixed mortar and concrete                         297
# Concrete blocks and bricks                              297
# Other concrete products including precast               297
# Other concrete products (excluding precast concrete)    297
# Structural steel and reinforcing metal                  297
# Rough timber (hardwood)                                 297
# Structural steel                                        297
# Other structural steel                                  297
# Structural steel fabricated metal                       297
# Reinforcing metal                                       297
# Other steel products                                    297
# Rough timber (including plain sawn)                     297
# Rough timber (softwood)                                 297
# All other products                                      297
# Name: Type of Material, dtype: int64

# %%
len(df_wpm["Type of Material"].unique())
# Out:
# 40

# %%
df_wpm.columns
# Out:
# Index(['STATISTIC', 'Statistic Label', 'TLIST(M1)', 'Month', 'C01409V03262',
#        'Type of Material', 'UNIT', 'VALUE'],
#       dtype='object')

# %%
cols=["Date",'Month',"Material","Wholesale_Price_Index"]
df_wpm=df_wpm[['TLIST(M1)','Month','Type of Material','VALUE']]
df_wpm.columns=cols
df_wpm.head()
# Out:
#      Date         Month                Material  Wholesale_Price_Index
# 0  201501  2015 January               Materials                   99.2
# 1  201501  2015 January  Stone, sand and gravel                   95.7
# 2  201501  2015 January         Sand and gravel                   98.0
# 3  201501  2015 January                   Stone                   95.3
# 4  201501  2015 January                  Cement                  100.0

# %%
df_wpm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11880 entries, 0 to 11879
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   11880 non-null  int64
#  1   Month                  11880 non-null  object
#  2   Material               11880 non-null  object
#  3   Wholesale_Price_Index  11348 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 371.4+ KB

# %%
df_wpm['Date'] =df_wpm['Date'].astype(str)

# Extract year, month, and quarter into separate columns
df_wpm['Year'] = df_wpm['Date'].str[:4].astype(int)
df_wpm['Month'] = df_wpm['Date'].str[-2:].astype(int)
df_wpm['Quarter'] = pd.to_datetime(df_wpm['Date'], format='%Y%m').dt.quarter.astype(int)
df_wpm['Wholesale_Price_Index']=df_wpm['Wholesale_Price_Index'].astype(float)
df_wpm.head()
# Out:
#      Date  Month                Material  Wholesale_Price_Index  Year  Quarter
# 0  201501      1               Materials                   99.2  2015        1
# 1  201501      1  Stone, sand and gravel                   95.7  2015        1
# 2  201501      1         Sand and gravel                   98.0  2015        1
# 3  201501      1                   Stone                   95.3  2015        1
# 4  201501      1                  Cement                  100.0  2015        1

# %% [markdown]
# ### New Dwelling Completion

# %%
df_ndc=pd.read_csv('NDQ06.csv')
df_ndc.head()
# Out:
#   STATISTIC          STATISTIC Label  TLIST(Q1) Quarter C02342V02816  \
# 0     NDQ06  New Dwelling Completion      20111  2011Q1           06
# 1     NDQ06  New Dwelling Completion      20111  2011Q1           06
# 2     NDQ06  New Dwelling Completion      20111  2011Q1           06
# 3     NDQ06  New Dwelling Completion      20111  2011Q1           06
# 4     NDQ06  New Dwelling Completion      20111  2011Q1           06
#
#   Type of House                          C03789V04537        Local Authority  \
# 0  Single house  2ae19629-1434-13a3-e055-000000000001      Cork City Council
# 1  Single house  2ae19629-14a2-13a3-e055-000000000001   Clare County Council
# 2  Single house  2ae19629-149d-13a3-e055-000000000001   Cavan County Council
# 3  Single house  2ae19629-14a3-13a3-e055-000000000001    Cork County Council
# 4  Single house  2ae19629-1492-13a3-e055-000000000001  Carlow County Council
#
#      UNIT  VALUE
# 0  Number      8
# 1  Number     45
# 2  Number     21
# 3  Number    145
# 4  Number     17

# %%
df_ndc.groupby(['STATISTIC Label'])['STATISTIC Label'].count()
# Out:
# STATISTIC Label
# New Dwelling Completion    6272
# Name: STATISTIC Label, dtype: int64

# %%
df_ndc.columns
# Out:
# Index(['STATISTIC', 'STATISTIC Label', 'TLIST(Q1)', 'Quarter', 'C02342V02816',
#        'Type of House', 'C03789V04537', 'Local Authority', 'UNIT', 'VALUE'],
#       dtype='object')

# %%
df_ndc=df_ndc[['TLIST(Q1)', 'Quarter',
       'Type of House','Local Authority','VALUE']]
cols_ndc=['Date','Quarter','House_Type','Local_Authority','House_Count']
df_ndc.columns=cols_ndc
df_ndc.head()
# Out:
#     Date Quarter    House_Type        Local_Authority  House_Count
# 0  20111  2011Q1  Single house      Cork City Council            8
# 1  20111  2011Q1  Single house   Clare County Council           45
# 2  20111  2011Q1  Single house   Cavan County Council           21
# 3  20111  2011Q1  Single house    Cork County Council          145
# 4  20111  2011Q1  Single house  Carlow County Council           17

# %%
df_ndc['Date'] =df_ndc['Date'].astype(str)

# Extract year, month, and quarter into separate columns
df_ndc['Year'] = df_ndc['Date'].str[:4].astype(int)
df_ndc['Quarter'] = df_ndc['Date'].str[-1:].astype(int)
df_ndc['House_Count']=df_ndc['House_Count'].astype(int)
df_ndc.head()
# Out:
#     Date  Quarter    House_Type        Local_Authority  House_Count  Year
# 0  20111        1  Single house      Cork City Council            8  2011
# 1  20111        1  Single house   Clare County Council           45  2011
# 2  20111        1  Single house   Cavan County Council           21  2011
# 3  20111        1  Single house    Cork County Council          145  2011
# 4  20111        1  Single house  Carlow County Council           17  2011

# %%
df_ndc.groupby(['Local_Authority'])['Local_Authority'].count()
# Out:
# Local_Authority
# Carlow County Council                    196
# Cavan County Council                     196
# Clare County Council                     196
# Cork City Council                        196
# Cork County Council                      196
# Donegal County Council                   196
# Dublin City Council                      196
# Dún Laoghaire Rathdown County Council    196
# Fingal County Council                    196
# Galway City Council                      196
# Galway County Council                    196
# Ireland                                  196
# Kerry County Council                     196
# Kildare County Council                   196
# Kilkenny County Council                  196
# Laois County Council                     196
# Leitrim County Council                   196
# Limerick City & County Council           196
# Longford County Council                  196
# Louth County Council                     196
# Mayo County Council                      196
# Meath County Council                     196
# Monaghan County Council                  196
# Offaly County Council                    196
# Roscommon County Council                 196
# Sligo County Council                     196
# South Dublin County Council              196
# Tipperary County Council                 196
# Waterford City & County Council          196
# Westmeath County Council                 196
# Wexford County Council                   196
# Wicklow County Council                   196
# Name: Local_Authority, dtype: int64

# %%
df_ndc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6272 entries, 0 to 6271
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             6272 non-null   object
#  1   Quarter          6272 non-null   int64
#  2   House_Type       6272 non-null   object
#  3   Local_Authority  6272 non-null   object
#  4   House_Count      6272 non-null   int64
#  5   Year             6272 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 294.1+ KB

# %%
df_ndc=df_ndc[df_ndc['Local_Authority']=='Ireland']

df_ndc.head()
# Out:
#       Date  Quarter       House_Type Local_Authority  House_Count  Year
# 31   20111        1     Single house         Ireland         1156  2011
# 63   20111        1     Scheme house         Ireland          447  2011
# 95   20111        1        Apartment         Ireland          272  2011
# 127  20111        1  All house types         Ireland         1875  2011
# 159  20112        2     Single house         Ireland         1194  2011

# %% [markdown]
# ### world bank datasets

# %%
df_wb=pd.read_csv('a45487f0-09b6-40b6-9f3c-8f02629a613a_Data.csv')
df_wb
# Out:
#    Country Name Country Code  \
# 0       Ireland          IRL
# 1       Ireland          IRL
# 2       Ireland          IRL
# 3       Ireland          IRL
# 4       Ireland          IRL
# 5       Ireland          IRL
# 6       Ireland          IRL
# 7       Ireland          IRL
# 8       Ireland          IRL
# 9       Ireland          IRL
# 10      Ireland          IRL
# 11      Ireland          IRL
# 12      Ireland          IRL
# 13      Ireland          IRL
#
#                                           Series Name        Series Code  \
# 0                               GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 1                  Inflation, GDP deflator (annual %)  NY.GDP.DEFL.KD.ZG
# 2                                       Net migration        SM.POP.NETM
# 3                        Population growth (annual %)        SP.POP.GROW
# 4                                   Population, total        SP.POP.TOTL
# 5                Birth rate, crude (per 1,000 people)     SP.DYN.CBRT.IN
# 6               Gross national expenditure (% of GDP)     NE.DAB.TOTL.ZS
# 7                            Gross savings (% of GDP)     NY.GNS.ICTR.ZS
# 8   Industry (including construction), value added...  NV.IND.TOTL.KD.ZG
# 9                         Population ages 0-14, total     SP.POP.0014.TO
# 10                       Population ages 15-64, total     SP.POP.1564.TO
# 11                Population ages 65 and above, total     SP.POP.65UP.TO
# 12                                   Urban population        SP.URB.TOTL
# 13                                   Rural population        SP.RUR.TOTL
#
#     2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# 0    1.125690e+00   8.649351e+00   2.437045e+01   2.006654e+00   9.005342e+00
# 1    1.050319e+00   5.423289e-02   8.386291e+00   7.278224e-01   1.094922e+00
# 2   -1.201500e+04   7.140000e+02   1.313000e+04   1.897800e+04   2.920000e+04
# 3    5.265562e-01   7.310014e-01   9.448453e-01   1.128834e+00   1.088676e+00
# 4    4.623816e+06   4.657740e+06   4.701957e+06   4.755335e+06   4.807388e+06
# 5    1.490000e+01   1.440000e+01   1.390000e+01   1.340000e+01   1.290000e+01
# 6    8.089563e+01   8.149532e+01   7.125103e+01   8.411086e+01   7.869940e+01
# 7    2.079017e+01   2.391246e+01   3.024582e+01   3.362272e+01   3.435825e+01
# 8   -2.657287e+00   1.033226e+01   7.012389e+01  -1.267340e+00   4.234452e+00
# 9    9.958730e+05   1.000254e+06   1.004394e+06   1.008135e+06   1.009142e+06
# 10   3.047390e+06   3.058075e+06   3.080857e+06   3.110739e+06   3.141774e+06
# 11   5.805520e+05   5.994110e+05   6.167060e+05   6.364620e+05   6.564720e+05
# 12   2.873286e+06   2.903635e+06   2.940510e+06   2.983355e+06   3.026107e+06
# 13   1.750530e+06   1.754105e+06   1.761447e+06   1.771980e+06   1.781281e+06
#
#     2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  2021 [YR2021] 2022 [YR2022]
# 0    8.527541e+00   5.440937e+00   6.184538e+00   1.358825e+01            ..
# 1    1.075700e+00   3.571836e+00  -1.565279e+00   6.576432e-01            ..
# 2    3.364700e+04   2.911300e+04   1.532000e+04   1.532000e+04          9999
# 3    1.238875e+00   1.367627e+00   1.029111e+00   9.538981e-01            ..
# 4    4.867316e+06   4.934340e+06   4.985382e+06   5.033165e+06            ..
# 5    1.250000e+01   1.200000e+01   1.120000e+01   1.160000e+01            ..
# 6    7.118307e+01   9.622984e+01   8.140651e+01   6.060716e+01            ..
# 7    3.377500e+01   3.539443e+01   3.650919e+01   3.895320e+01            ..
# 8    1.082557e+01   2.315378e+00   2.034074e+01   2.032766e+01            ..
# 9    1.009790e+06   1.009477e+06   1.005941e+06   1.002263e+06            ..
# 10   3.178909e+06   3.222077e+06   3.254350e+06   3.284531e+06            ..
# 11   6.786170e+05   7.027860e+05   7.250910e+05   7.463710e+05            ..
# 12   3.074684e+06   3.128618e+06   3.173345e+06   3.216796e+06            ..
# 13   1.792632e+06   1.805722e+06   1.812037e+06   1.816369e+06            ..

# %%
df_wb.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]',
#        '2021 [YR2021]', '2022 [YR2022]'],
#       dtype='object')

# %%
cols_wb=['Country_Name', 'Country_Code', 'Series_Name', 'Series_Code','2013', '2014', '2015', '2016','2017', '2018', '2019', '2020','2021', '2022']
df_wb.columns=cols_wb
df_wb=df_wb[['Series_Name','2013', '2014', '2015', '2016','2017', '2018', '2019', '2020','2021', '2022']]
df_wb.head()
# Out:
#                           Series_Name          2013          2014  \
# 0               GDP growth (annual %)  1.125690e+00  8.649351e+00
# 1  Inflation, GDP deflator (annual %)  1.050319e+00  5.423289e-02
# 2                       Net migration -1.201500e+04  7.140000e+02
# 3        Population growth (annual %)  5.265562e-01  7.310014e-01
# 4                   Population, total  4.623816e+06  4.657740e+06
#
#            2015          2016          2017          2018          2019  \
# 0  2.437045e+01  2.006654e+00  9.005342e+00  8.527541e+00  5.440937e+00
# 1  8.386291e+00  7.278224e-01  1.094922e+00  1.075700e+00  3.571836e+00
# 2  1.313000e+04  1.897800e+04  2.920000e+04  3.364700e+04  2.911300e+04
# 3  9.448453e-01  1.128834e+00  1.088676e+00  1.238875e+00  1.367627e+00
# 4  4.701957e+06  4.755335e+06  4.807388e+06  4.867316e+06  4.934340e+06
#
#            2020          2021  2022
# 0  6.184538e+00  1.358825e+01    ..
# 1 -1.565279e+00  6.576432e-01    ..
# 2  1.532000e+04  1.532000e+04  9999
# 3  1.029111e+00  9.538981e-01    ..
# 4  4.985382e+06  5.033165e+06    ..

# %%
# Melt the DataFrame to unpivot the years
df_melt = pd.melt(df_wb, id_vars='Series_Name', var_name='Year', value_name='Value')

# Pivot the melted DataFrame
df_pivot = df_melt.pivot(index='Year', columns='Series_Name', values='Value')

# Reset the index
df_pivot = df_pivot.reset_index()
df_pivot
# Out:
# Series_Name  Year Birth rate, crude (per 1,000 people) GDP growth (annual %)  \
# 0            2013                                 14.9               1.12569
# 1            2014                                 14.4              8.649351
# 2            2015                                 13.9             24.370445
# 3            2016                                 13.4              2.006654
# 4            2017                                 12.9              9.005342
# 5            2018                                 12.5              8.527541
# 6            2019                                 12.0              5.440937
# 7            2020                                 11.2              6.184538
# 8            2021                                 11.6             13.588247
# 9            2022                                   ..                    ..
#
# Series_Name Gross national expenditure (% of GDP) Gross savings (% of GDP)  \
# 0                                       80.895626                20.790172
# 1                                       81.495316                23.912461
# 2                                       71.251034                30.245823
# 3                                       84.110857                33.622721
# 4                                       78.699402                34.358252
# 5                                       71.183072                33.775003
# 6                                       96.229836                35.394434
# 7                                       81.406506                36.509194
# 8                                       60.607163                38.953199
# 9                                              ..                       ..
#
# Series_Name Industry (including construction), value added (annual % growth)  \
# 0                                                    -2.657287
# 1                                                    10.332259
# 2                                                    70.123892
# 3                                                     -1.26734
# 4                                                     4.234452
# 5                                                    10.825575
# 6                                                     2.315378
# 7                                                    20.340745
# 8                                                    20.327664
# 9                                                           ..
#
# Series_Name Inflation, GDP deflator (annual %) Net migration  \
# 0                                     1.050319      -12015.0
# 1                                     0.054233         714.0
# 2                                     8.386291       13130.0
# 3                                     0.727822       18978.0
# 4                                     1.094922       29200.0
# 5                                       1.0757       33647.0
# 6                                     3.571836       29113.0
# 7                                    -1.565279       15320.0
# 8                                     0.657643       15320.0
# 9                                           ..          9999
#
# Series_Name Population ages 0-14, total Population ages 15-64, total  \
# 0                              995873.0                    3047390.0
# 1                             1000254.0                    3058075.0
# 2                             1004394.0                    3080857.0
# 3                             1008135.0                    3110739.0
# 4                             1009142.0                    3141774.0
# 5                             1009790.0                    3178909.0
# 6                             1009477.0                    3222077.0
# 7                             1005941.0                    3254350.0
# 8                             1002263.0                    3284531.0
# 9                                    ..                           ..
#
# Series_Name Population ages 65 and above, total Population growth (annual %)  \
# 0                                      580552.0                     0.526556
# 1                                      599411.0                     0.731001
# 2                                      616706.0                     0.944845
# 3                                      636462.0                     1.128834
# 4                                      656472.0                     1.088676
# 5                                      678617.0                     1.238875
# 6                                      702786.0                     1.367627
# 7                                      725091.0                     1.029111
# 8                                      746371.0                     0.953898
# 9                                            ..                           ..
#
# Series_Name Population, total Rural population Urban population
# 0                   4623816.0        1750530.0        2873286.0
# 1                   4657740.0        1754105.0        2903635.0
# 2                   4701957.0        1761447.0        2940510.0
# 3                   4755335.0        1771980.0        2983355.0
# 4                   4807388.0        1781281.0        3026107.0
# 5                   4867316.0        1792632.0        3074684.0
# 6                   4934340.0        1805722.0        3128618.0
# 7                   4985382.0        1812037.0        3173345.0
# 8                   5033165.0        1816369.0        3216796.0
# 9                          ..               ..               ..

# %%
df_pivot.drop(9, inplace=True)
df_pivot
# Out:
# Series_Name  Year Birth rate, crude (per 1,000 people) GDP growth (annual %)  \
# 0            2013                                 14.9               1.12569
# 1            2014                                 14.4              8.649351
# 2            2015                                 13.9             24.370445
# 3            2016                                 13.4              2.006654
# 4            2017                                 12.9              9.005342
# 5            2018                                 12.5              8.527541
# 6            2019                                 12.0              5.440937
# 7            2020                                 11.2              6.184538
# 8            2021                                 11.6             13.588247
#
# Series_Name Gross national expenditure (% of GDP) Gross savings (% of GDP)  \
# 0                                       80.895626                20.790172
# 1                                       81.495316                23.912461
# 2                                       71.251034                30.245823
# 3                                       84.110857                33.622721
# 4                                       78.699402                34.358252
# 5                                       71.183072                33.775003
# 6                                       96.229836                35.394434
# 7                                       81.406506                36.509194
# 8                                       60.607163                38.953199
#
# Series_Name Industry (including construction), value added (annual % growth)  \
# 0                                                    -2.657287
# 1                                                    10.332259
# 2                                                    70.123892
# 3                                                     -1.26734
# 4                                                     4.234452
# 5                                                    10.825575
# 6                                                     2.315378
# 7                                                    20.340745
# 8                                                    20.327664
#
# Series_Name Inflation, GDP deflator (annual %) Net migration  \
# 0                                     1.050319      -12015.0
# 1                                     0.054233         714.0
# 2                                     8.386291       13130.0
# 3                                     0.727822       18978.0
# 4                                     1.094922       29200.0
# 5                                       1.0757       33647.0
# 6                                     3.571836       29113.0
# 7                                    -1.565279       15320.0
# 8                                     0.657643       15320.0
#
# Series_Name Population ages 0-14, total Population ages 15-64, total  \
# 0                              995873.0                    3047390.0
# 1                             1000254.0                    3058075.0
# 2                             1004394.0                    3080857.0
# 3                             1008135.0                    3110739.0
# 4                             1009142.0                    3141774.0
# 5                             1009790.0                    3178909.0
# 6                             1009477.0                    3222077.0
# 7                             1005941.0                    3254350.0
# 8                             1002263.0                    3284531.0
#
# Series_Name Population ages 65 and above, total Population growth (annual %)  \
# 0                                      580552.0                     0.526556
# 1                                      599411.0                     0.731001
# 2                                      616706.0                     0.944845
# 3                                      636462.0                     1.128834
# 4                                      656472.0                     1.088676
# 5                                      678617.0                     1.238875
# 6                                      702786.0                     1.367627
# 7                                      725091.0                     1.029111
# 8                                      746371.0                     0.953898
#
# Series_Name Population, total Rural population Urban population
# 0                   4623816.0        1750530.0        2873286.0
# 1                   4657740.0        1754105.0        2903635.0
# 2                   4701957.0        1761447.0        2940510.0
# 3                   4755335.0        1771980.0        2983355.0
# 4                   4807388.0        1781281.0        3026107.0
# 5                   4867316.0        1792632.0        3074684.0
# 6                   4934340.0        1805722.0        3128618.0
# 7                   4985382.0        1812037.0        3173345.0
# 8                   5033165.0        1816369.0        3216796.0

# %%
df_pivot.columns
# Out:
# Index(['Year', 'Birth rate, crude (per 1,000 people)', 'GDP growth (annual %)',
#        'Gross national expenditure (% of GDP)', 'Gross savings (% of GDP)',
#        'Industry (including construction), value added (annual % growth)',
#        'Inflation, GDP deflator (annual %)', 'Net migration',
#        'Population ages 0-14, total', 'Population ages 15-64, total',
#        'Population ages 65 and above, total', 'Population growth (annual %)',
#        'Population, total', 'Rural population', 'Urban population'],
#       dtype='object', name='Series_Name')

# %%
cols_new=['Year','Birth rate', 'GDP growth', 'Gross_National_Expenditure', 'Gross_Savings', 'Industry', 'Inflation', 'Net_Migration', ' Population_0-14', 
            'Population _5-64', 'Population_above_65', 'Population growth', 'Population', 'Rural population', 'Urban population']
df_pivot.columns=cols_new
df_pivot[cols_new]=df_pivot[cols_new].astype(float)
df_pivot['Year']=df_pivot['Year'].astype(int)

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        9 non-null      int64
#  1   Birth rate                  9 non-null      float64
#  2   GDP growth                  9 non-null      float64
#  3   Gross_National_Expenditure  9 non-null      float64
#  4   Gross_Savings               9 non-null      float64
#  5   Industry                    9 non-null      float64
#  6   Inflation                   9 non-null      float64
#  7   Net_Migration               9 non-null      float64
#  8    Population_0-14            9 non-null      float64
#  9   Population _5-64            9 non-null      float64
#  10  Population_above_65         9 non-null      float64
#  11  Population growth           9 non-null      float64
#  12  Population                  9 non-null      float64
#  13  Rural population            9 non-null      float64
#  14  Urban population            9 non-null      float64
# dtypes: float64(14), int64(1)
# memory usage: 1.2 KB

# %% [markdown]
# ### BEQ04 - Indices of Total Production in Building and Construction Sector (Base 2015=100)
# #### https://data.gov.ie/dataset/beq04-indices-of-total-production-in-building-and-construction-sector-base-2015100?package_type=dataset

# %%
df_bc=pd.read_csv('BEQ04.20230512223829.csv')
df_bc.head()
# Out:
#   STATISTIC                                    Statistic Label  TLIST(Q1)  \
# 0  BEQ04C01  Value of Production Index in Building and Cons...      20001
# 1  BEQ04C01  Value of Production Index in Building and Cons...      20001
# 2  BEQ04C01  Value of Production Index in Building and Cons...      20001
# 3  BEQ04C01  Value of Production Index in Building and Cons...      20001
# 4  BEQ04C01  Value of Production Index in Building and Cons...      20001
#
#   Quarter C02402V02895       Type of Building and Construction           UNIT  \
# 0  2000Q1            -           All building and construction  Base 2015=100
# 1  2000Q1           11  Building (excluding civil engineering)  Base 2015=100
# 2  2000Q1          111                    Residential building  Base 2015=100
# 3  2000Q1          112                Non-residential building  Base 2015=100
# 4  2000Q1           12                       Civil engineering  Base 2015=100
#
#         VALUE
# 0  143.514977
# 1  182.795802
# 2  279.281551
# 3  115.359508
# 4   60.438887

# %%
df_bc.columns
# Out:
# Index(['STATISTIC', 'Statistic Label', 'TLIST(Q1)', 'Quarter', 'C02402V02895',
#        'Type of Building and Construction', 'UNIT', 'VALUE'],
#       dtype='object')

# %%
df_bc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1840 entries, 0 to 1839
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   STATISTIC                          1840 non-null   object
#  1   Statistic Label                    1840 non-null   object
#  2   TLIST(Q1)                          1840 non-null   int64
#  3   Quarter                            1840 non-null   object
#  4   C02402V02895                       1840 non-null   object
#  5   Type of Building and Construction  1840 non-null   object
#  6   UNIT                               1840 non-null   object
#  7   VALUE                              1840 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 115.1+ KB

# %%
cols_bc=['Date', 'Quarter','Type_of_Building_Construction','Indices_Building_Construction']
df_bc=df_bc[['TLIST(Q1)', 'Quarter', 'Type of Building and Construction','VALUE']]
df_bc.columns=cols_bc

# %%
df_bc['Date']=df_bc['Date'].astype(str)
df_bc['Year'] = df_bc['Date'].str[:4].astype(int)
df_bc['Quarter'] = df_bc['Date'].str[-1:].astype(int)
df_bc['Indices_Building_Construction']=df_bc['Indices_Building_Construction'].astype(float)
df_bc.drop('Date',axis=1,inplace=True)
df_bc.head()
# Out:
#    Quarter           Type_of_Building_Construction  \
# 0        1           All building and construction
# 1        1  Building (excluding civil engineering)
# 2        1                    Residential building
# 3        1                Non-residential building
# 4        1                       Civil engineering
#
#    Indices_Building_Construction  Year
# 0                     143.514977  2000
# 1                     182.795802  2000
# 2                     279.281551  2000
# 3                     115.359508  2000
# 4                      60.438887  2000

# %% [markdown]
# ### europen uninion construction datasets for coparing
# https://ec.europa.eu/eurostat/databrowser/view/STS_COPI_Q__custom_6244165/default/table?lang=en

# %%
df_eu_conuntries=pd.read_csv("sts_copi_q__custom_6244165_page_linear.csv")
df_eu_conuntries.head()
# Out:
#                 DATAFLOW        LAST UPDATE freq indic_bt  \
# 0  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 1  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 2  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 3  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 4  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
#
#                 cpa2_1 s_adj unit geo TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0  CPA_F41001_X_410014   NSA  I15  AL     2002-Q1       85.2        s
# 1  CPA_F41001_X_410014   NSA  I15  AL     2002-Q2       85.7        s
# 2  CPA_F41001_X_410014   NSA  I15  AL     2002-Q3       86.6        s
# 3  CPA_F41001_X_410014   NSA  I15  AL     2002-Q4       87.5        s
# 4  CPA_F41001_X_410014   NSA  I15  AL     2003-Q1       86.7        s

# %%
df_eu_conuntries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4089 entries, 0 to 4088
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATAFLOW     4089 non-null   object
#  1   LAST UPDATE  4089 non-null   object
#  2   freq         4089 non-null   object
#  3   indic_bt     4089 non-null   object
#  4   cpa2_1       4089 non-null   object
#  5   s_adj        4089 non-null   object
#  6   unit         4089 non-null   object
#  7   geo          4089 non-null   object
#  8   TIME_PERIOD  4089 non-null   object
#  9   OBS_VALUE    4088 non-null   float64
#  10  OBS_FLAG     2233 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 351.5+ KB

# %%
df_eu_conuntries['TIME_PERIOD']=df_eu_conuntries['TIME_PERIOD'].astype(str)
df_eu_conuntries['Year'] = df_eu_conuntries['TIME_PERIOD'].str[:4].astype(int)
df_eu_conuntries['Quarter'] = df_eu_conuntries['TIME_PERIOD'].str[-1:].astype(int)
df_eu_conuntries['OBS_VALUE']=df_eu_conuntries['OBS_VALUE'].astype(float)
df_eu_conuntries.drop('TIME_PERIOD',axis=1,inplace=True)
df_eu_conuntries.head()
# Out:
#                 DATAFLOW        LAST UPDATE freq indic_bt  \
# 0  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 1  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 2  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 3  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 4  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
#
#                 cpa2_1 s_adj unit geo  OBS_VALUE OBS_FLAG  Year  Quarter
# 0  CPA_F41001_X_410014   NSA  I15  AL       85.2        s  2002        1
# 1  CPA_F41001_X_410014   NSA  I15  AL       85.7        s  2002        2
# 2  CPA_F41001_X_410014   NSA  I15  AL       86.6        s  2002        3
# 3  CPA_F41001_X_410014   NSA  I15  AL       87.5        s  2002        4
# 4  CPA_F41001_X_410014   NSA  I15  AL       86.7        s  2003        1

# %% [markdown]
# ### Merge datasets

# %%
df_wb
# Out:
#                                           Series_Name          2013  \
# 0                               GDP growth (annual %)  1.125690e+00
# 1                  Inflation, GDP deflator (annual %)  1.050319e+00
# 2                                       Net migration -1.201500e+04
# 3                        Population growth (annual %)  5.265562e-01
# 4                                   Population, total  4.623816e+06
# 5                Birth rate, crude (per 1,000 people)  1.490000e+01
# 6               Gross national expenditure (% of GDP)  8.089563e+01
# 7                            Gross savings (% of GDP)  2.079017e+01
# 8   Industry (including construction), value added... -2.657287e+00
# 9                         Population ages 0-14, total  9.958730e+05
# 10                       Population ages 15-64, total  3.047390e+06
# 11                Population ages 65 and above, total  5.805520e+05
# 12                                   Urban population  2.873286e+06
# 13                                   Rural population  1.750530e+06
#
#             2014          2015          2016          2017          2018  \
# 0   8.649351e+00  2.437045e+01  2.006654e+00  9.005342e+00  8.527541e+00
# 1   5.423289e-02  8.386291e+00  7.278224e-01  1.094922e+00  1.075700e+00
# 2   7.140000e+02  1.313000e+04  1.897800e+04  2.920000e+04  3.364700e+04
# 3   7.310014e-01  9.448453e-01  1.128834e+00  1.088676e+00  1.238875e+00
# 4   4.657740e+06  4.701957e+06  4.755335e+06  4.807388e+06  4.867316e+06
# 5   1.440000e+01  1.390000e+01  1.340000e+01  1.290000e+01  1.250000e+01
# 6   8.149532e+01  7.125103e+01  8.411086e+01  7.869940e+01  7.118307e+01
# 7   2.391246e+01  3.024582e+01  3.362272e+01  3.435825e+01  3.377500e+01
# 8   1.033226e+01  7.012389e+01 -1.267340e+00  4.234452e+00  1.082557e+01
# 9   1.000254e+06  1.004394e+06  1.008135e+06  1.009142e+06  1.009790e+06
# 10  3.058075e+06  3.080857e+06  3.110739e+06  3.141774e+06  3.178909e+06
# 11  5.994110e+05  6.167060e+05  6.364620e+05  6.564720e+05  6.786170e+05
# 12  2.903635e+06  2.940510e+06  2.983355e+06  3.026107e+06  3.074684e+06
# 13  1.754105e+06  1.761447e+06  1.771980e+06  1.781281e+06  1.792632e+06
#
#             2019          2020          2021  2022
# 0   5.440937e+00  6.184538e+00  1.358825e+01    ..
# 1   3.571836e+00 -1.565279e+00  6.576432e-01    ..
# 2   2.911300e+04  1.532000e+04  1.532000e+04  9999
# 3   1.367627e+00  1.029111e+00  9.538981e-01    ..
# 4   4.934340e+06  4.985382e+06  5.033165e+06    ..
# 5   1.200000e+01  1.120000e+01  1.160000e+01    ..
# 6   9.622984e+01  8.140651e+01  6.060716e+01    ..
# 7   3.539443e+01  3.650919e+01  3.895320e+01    ..
# 8   2.315378e+00  2.034074e+01  2.032766e+01    ..
# 9   1.009477e+06  1.005941e+06  1.002263e+06    ..
# 10  3.222077e+06  3.254350e+06  3.284531e+06    ..
# 11  7.027860e+05  7.250910e+05  7.463710e+05    ..
# 12  3.128618e+06  3.173345e+06  3.216796e+06    ..
# 13  1.805722e+06  1.812037e+06  1.816369e+06    ..

# %%
# create a final df with merging only Iriland datasets
df_final=df_wpm.merge(df_ndc,on=['Year','Quarter'])
df_final.head()
# Out:
#    Date_x  Month                Material  Wholesale_Price_Index  Year  \
# 0  201501      1               Materials                   99.2  2015
# 1  201501      1               Materials                   99.2  2015
# 2  201501      1               Materials                   99.2  2015
# 3  201501      1               Materials                   99.2  2015
# 4  201501      1  Stone, sand and gravel                   95.7  2015
#
#    Quarter Date_y       House_Type Local_Authority  House_Count
# 0        1  20151     Single house         Ireland          659
# 1        1  20151     Scheme house         Ireland          606
# 2        1  20151        Apartment         Ireland          106
# 3        1  20151  All house types         Ireland         1371
# 4        1  20151     Single house         Ireland          659

# %%
df_final=df_final.merge(df_bc,on=['Year','Quarter'])
df_final.head()
# Out:
#    Date_x  Month   Material  Wholesale_Price_Index  Year  Quarter Date_y  \
# 0  201501      1  Materials                   99.2  2015        1  20151
# 1  201501      1  Materials                   99.2  2015        1  20151
# 2  201501      1  Materials                   99.2  2015        1  20151
# 3  201501      1  Materials                   99.2  2015        1  20151
# 4  201501      1  Materials                   99.2  2015        1  20151
#
#      House_Type Local_Authority  House_Count  \
# 0  Single house         Ireland          659
# 1  Single house         Ireland          659
# 2  Single house         Ireland          659
# 3  Single house         Ireland          659
# 4  Single house         Ireland          659
#
#             Type_of_Building_Construction  Indices_Building_Construction
# 0           All building and construction                      86.994370
# 1  Building (excluding civil engineering)                      87.219016
# 2                    Residential building                      85.585237
# 3                Non-residential building                      87.472137
# 4                       Civil engineering                      85.970980

# %%
df_final=df_final.merge(df_pivot,on='Year')
df_final.head()
# Out:
#    Date_x  Month   Material  Wholesale_Price_Index  Year  Quarter Date_y  \
# 0  201501      1  Materials                   99.2  2015        1  20151
# 1  201501      1  Materials                   99.2  2015        1  20151
# 2  201501      1  Materials                   99.2  2015        1  20151
# 3  201501      1  Materials                   99.2  2015        1  20151
# 4  201501      1  Materials                   99.2  2015        1  20151
#
#      House_Type Local_Authority  House_Count  ...   Industry  Inflation  \
# 0  Single house         Ireland          659  ...  70.123892   8.386291
# 1  Single house         Ireland          659  ...  70.123892   8.386291
# 2  Single house         Ireland          659  ...  70.123892   8.386291
# 3  Single house         Ireland          659  ...  70.123892   8.386291
# 4  Single house         Ireland          659  ...  70.123892   8.386291
#
#    Net_Migration   Population_0-14  Population _5-64  Population_above_65  \
# 0        13130.0         1004394.0         3080857.0             616706.0
# 1        13130.0         1004394.0         3080857.0             616706.0
# 2        13130.0         1004394.0         3080857.0             616706.0
# 3        13130.0         1004394.0         3080857.0             616706.0
# 4        13130.0         1004394.0         3080857.0             616706.0
#
#    Population growth  Population  Rural population  Urban population
# 0           0.944845   4701957.0         1761447.0         2940510.0
# 1           0.944845   4701957.0         1761447.0         2940510.0
# 2           0.944845   4701957.0         1761447.0         2940510.0
# 3           0.944845   4701957.0         1761447.0         2940510.0
# 4           0.944845   4701957.0         1761447.0         2940510.0
#
# [5 rows x 26 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 806400 entries, 0 to 806399
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Date_x                         806400 non-null  object
#  1   Month                          806400 non-null  int64
#  2   Material                       806400 non-null  object
#  3   Wholesale_Price_Index          764800 non-null  float64
#  4   Year                           806400 non-null  int64
#  5   Quarter                        806400 non-null  int64
#  6   Date_y                         806400 non-null  object
#  7   House_Type                     806400 non-null  object
#  8   Local_Authority                806400 non-null  object
#  9   House_Count                    806400 non-null  int64
#  10  Type_of_Building_Construction  806400 non-null  object
#  11  Indices_Building_Construction  806400 non-null  float64
#  12  Birth rate                     806400 non-null  float64
#  13  GDP growth                     806400 non-null  float64
#  14  Gross_National_Expenditure     806400 non-null  float64
#  15  Gross_Savings                  806400 non-null  float64
#  16  Industry                       806400 non-null  float64
#  17  Inflation                      806400 non-null  float64
#  18  Net_Migration                  806400 non-null  float64
#  19   Population_0-14               806400 non-null  float64
#  20  Population _5-64               806400 non-null  float64
#  21  Population_above_65            806400 non-null  float64
#  22  Population growth              806400 non-null  float64
#  23  Population                     806400 non-null  float64
#  24  Rural population               806400 non-null  float64
#  25  Urban population               806400 non-null  float64
# dtypes: float64(16), int64(4), object(6)
# memory usage: 166.1+ MB

# %% [markdown]
# ### Comparing EU datasets
# * Construction producer prices or costs, new residential buildings
# * EU data sets include Europen Union countries
# * Datasets illustrates index quarterly
# * Comparisons will be made between Ireland and other European Union countries using the following features;
#  - geo (categorical feature) : country codes
#  - obs_value (numerical feature) : Construction producer prices or costs index
#  - year
#  - quarter
#
# ####  https://pypi.org/project/pycountry/
# * country codes convert from alpha 2 to apha-3

# %%
df_eu_conuntries.head()
# Out:
#                 DATAFLOW        LAST UPDATE freq indic_bt  \
# 0  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 1  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 2  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 3  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
# 4  ESTAT:STS_COPI_Q(1.0)  17/05/23 11:00:00    Q     CSTO
#
#                 cpa2_1 s_adj unit geo  OBS_VALUE OBS_FLAG  Year  Quarter
# 0  CPA_F41001_X_410014   NSA  I15  AL       85.2        s  2002        1
# 1  CPA_F41001_X_410014   NSA  I15  AL       85.7        s  2002        2
# 2  CPA_F41001_X_410014   NSA  I15  AL       86.6        s  2002        3
# 3  CPA_F41001_X_410014   NSA  I15  AL       87.5        s  2002        4
# 4  CPA_F41001_X_410014   NSA  I15  AL       86.7        s  2003        1

# %%
df_eu_conuntries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4089 entries, 0 to 4088
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATAFLOW     4089 non-null   object
#  1   LAST UPDATE  4089 non-null   object
#  2   freq         4089 non-null   object
#  3   indic_bt     4089 non-null   object
#  4   cpa2_1       4089 non-null   object
#  5   s_adj        4089 non-null   object
#  6   unit         4089 non-null   object
#  7   geo          4089 non-null   object
#  8   OBS_VALUE    4088 non-null   float64
#  9   OBS_FLAG     2233 non-null   object
#  10  Year         4089 non-null   int64
#  11  Quarter      4089 non-null   int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 383.5+ KB

# %%
df_eu_conuntries_new=df_eu_conuntries[['geo','OBS_VALUE','Year','Quarter']]
df_eu_conuntries_new.describe(include='all')
# Out:
#          geo    OBS_VALUE         Year      Quarter
# count   4089  4088.000000  4089.000000  4089.000000
# unique    38          NaN          NaN          NaN
# top       FR          NaN          NaN          NaN
# freq     277          NaN          NaN          NaN
# mean     NaN    88.233317  2006.926877     2.496209
# std      NaN    32.213649    11.998421     1.119585
# min      NaN     6.000000  1953.000000     1.000000
# 25%      NaN    71.700000  2002.000000     1.000000
# 50%      NaN    93.700000  2009.000000     2.000000
# 75%      NaN   102.000000  2016.000000     3.000000
# max      NaN   696.900000  2023.000000     4.000000

# %%
# convert alpha-2 code to alpha-3 code
df_eu_conuntries_new['geo_3'] = df_eu_conuntries_new['geo'].apply(lambda x: pycountry.countries.get(alpha_2=x).alpha_3 if pycountry.countries.get(alpha_2=x) else None)

df_eu_conuntries_new.head()
# Out:
# /var/folders/py/4cct40495x36bqlv8mh9q3m00000gn/T/ipykernel_8463/2530568235.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eu_conuntries_new['geo_3'] = df_eu_conuntries_new['geo'].apply(lambda x: pycountry.countries.get(alpha_2=x).alpha_3 if pycountry.countries.get(alpha_2=x) else None)
#   geo  OBS_VALUE  Year  Quarter geo_3
# 0  AL       85.2  2002        1   ALB
# 1  AL       85.7  2002        2   ALB
# 2  AL       86.6  2002        3   ALB
# 3  AL       87.5  2002        4   ALB
# 4  AL       86.7  2003        1   ALB

# %% [markdown]
# * OBS_VALUE's statistics show that there is a significant difference between min and max values and the feature's mean also shows it is the left skew and it shows that majority of outliers mean greater than 3rd quartile.

# %%
#boxplot for loking index in general


# https://seaborn.pydata.org/examples/horizontal_boxplot.html

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(10, 18))
ax.set_xscale("log")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="OBS_VALUE", y="geo_3", data=df_eu_conuntries_new,
            whis=[0, 100], width=0.7, palette="vlag")

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
ax.set_title("Boxplot of construction producer prices or costs in EU Countries ",fontsize=14)
#plt.xticks(rotation='vertical')
sns.despine(trim=True, left=True)

# %% [markdown]
# ### geo

# %%
df_eu_conuntries_new.sort_values(by=["Year"],inplace=True)
# Out:
# /var/folders/py/4cct40495x36bqlv8mh9q3m00000gn/T/ipykernel_8463/2171315446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_eu_conuntries_new.sort_values(by=["Year"],inplace=True)

# %%
fig = px.choropleth(df_eu_conuntries_new, locations="geo_3",
                    color="OBS_VALUE", 
                    # column to add to hover information
                    animation_frame="Year", 
                    # column on which to animate
                    color_continuous_scale=px.colors.sequential.Reds,
                    locationmode='ISO-3')

                    
fig.update_layout(
    title_text = 'Changing the construction producer prices or costs in EU Countries by year',
    geo = dict(projection_type='natural earth', scope='europe') 
)
fig.show()
# Out:
# <div>                            <div id="c6bc4f89-5240-4769-ac00-4a527a907acf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6bc4f89-5240-4769-ac00-4a527a907acf")) {                    Plotly.newPlot(                        "c6bc4f89-5240-4769-ac00-4a527a907acf",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Year=1953<br>geo_3=%{location}<br>OBS_VALUE=%{z}<extra></extra>","locationmode":"ISO-3","locations":["FRA"],"name":"","z":[6.2],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}], ...

# %%
# lets look last 10 years
df_eu_last_3years=df_eu_conuntries_new[df_eu_conuntries_new['Year']>2019]

# %%
fig = px.choropleth(df_eu_last_3years, locations="geo_3",
                    color="OBS_VALUE", 
                    # column to add to hover information
                    #animation_frame="Year", 
                    # column on which to animate
                    color_continuous_scale=px.colors.sequential.Reds,
                    locationmode='ISO-3')

                    
fig.update_layout(
    title_text = 'Changing the construction producer prices or costs in EU Countries by year',
    geo = dict(projection_type='natural earth',scope='europe' ) 
)
fig.show()
# Out:
# <div>                            <div id="a4695c32-e9a9-46b1-9044-80a0fc82a0dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4695c32-e9a9-46b1-9044-80a0fc82a0dd")) {                    Plotly.newPlot(                        "a4695c32-e9a9-46b1-9044-80a0fc82a0dd",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"geo_3=%{location}<br>OBS_VALUE=%{z}<extra></extra>","locationmode":"ISO-3","locations":["HRV","HRV","HRV","HRV","MLT","FRA","ESP",null,"CHE","CHE","TUR","TUR","TUR","TUR","CHE","CHE","FIN","FIN","FIN","FIN","CYP","CYP","CYP","CYP",null,null,null,null,null,"ESP","ESP","ESP",null,"FRA","FRA","SVN","SVN","SVN","SVN","ALB","ALB","ALB","ALB","DNK","FRA","DNK","DNK","BGR","SVK","SVK","SVK","SVK","BGR","BGR",null,null,null,"DNK","BGR",null,"NOR","NLD","NLD","LTU","LTU","POL","IRL","IRL","IRL","IRL","NLD","POL","POL","LVA","LVA","LVA","LVA","LTU","AUT","LUX","LUX","POL","BEL","BEL","MKD","MNE","MNE","MNE","MNE","NOR","NOR","ITA","ITA","ITA","ITA","NOR","ROU","ROU","ROU","ROU","BEL",null,null,null,"NLD",null,"LUX",null,"LUX","LTU","DEU","DEU",null,"BIH","BIH","HUN","BIH","MKD","HUN","HUN","HUN","SWE","SWE","SWE","SWE","AUT","AUT","AUT","MLT","MLT","MLT","DEU","DEU","BIH","BEL","PRT","EST","EST","CZE","PRT","PRT","MKD","CZE","CZE","EST","PRT",null,null,"MKD","CZE","EST","LUX","MNE",null,"MNE","LUX","SVK","MNE","MNE","SVK","PRT","PRT","PRT","PRT","SVK","SVK","BGR","LUX","LVA","LVA",null,null,null,null,"CHE","CHE","CHE","CHE","DEU","DEU","DEU","DEU","BIH","BIH","BIH","BIH","TUR","TUR","TUR","LVA","LUX","LVA","NOR","BGR","BGR","BGR","FIN","FIN","FIN","FIN",null,null,null,null,"NOR","NOR","POL","POL","POL","POL","ESP","ESP","ESP","ESP","NOR","AUT","MKD","AUT","EST","FRA","FRA","FRA","FRA","CZE","CZE","IRL","IRL","IRL","IRL","MKD","SVN","SVN","AUT","SVN",null,null,null,null,"ALB","EST","ALB","EST","CZE","SWE","SWE","SWE","SWE","MLT","MLT","MLT","MLT","HUN","HUN","HUN","HRV","HRV","HRV","HRV","HUN","EST","BEL","BEL","BEL","BEL","CZE","ALB","SVN","ITA","ROU",null,"LTU","MKD","TUR","ROU","NLD","DNK","DNK","DNK","DNK","ALB","NLD","NLD","NLD","LTU","LTU","ROU","ROU","MKD","CYP","ITA","AUT","ITA","CYP","ITA","LTU",null,null,"CYP","CYP","NLD","MLT","NOR","BIH","BIH","TUR","NLD","MNE","MLT","BIH","MNE","MNE","MNE","MLT","MLT","BIH","NOR","EST","NLD",null,"FIN",null,null,null,"CYP","CYP","CYP","FIN","CYP","FIN","FIN","MKD","MKD","MKD","MKD","EST","EST","EST","NOR","NOR","CHE","CHE","CHE","CHE","NLD","TUR","SWE","TUR","IRL","SVN","SVN","SVN","SVN","ALB","ALB","ALB","ALB","ITA","ITA","ITA","ITA","ROU","ROU","ROU",null,"DNK","DNK","DNK","DNK",null,"TUR","IRL","LTU","IRL","DEU","SWE","SWE","SWE","HRV","HRV","HRV","HRV","HUN","HUN","HUN","HUN","BEL","BEL","BEL","BEL","FRA","FRA","FRA","FRA","CZE","CZE","CZE","CZE","DEU","LTU","LTU","LUX","LTU",null,null,null,"LUX","LUX","POL","POL","POL","POL","ESP","BGR","ESP","ESP","LVA","LVA","LVA","LVA",null,null,null,null,"DEU","DEU","ESP","BGR","IRL","BGR",null,null,null,"AUT","AUT","AUT","AUT","BGR","PRT","PRT","PRT","SVK","SVK","SVK","LUX","PRT","SVK","NOR","SWE","IRL","DEU","SVK","FIN",null,"EST","HUN","PRT","ITA","AUT","LTU"],"name":"","z":[110.8,112.5,112.6,107.8,106.7,108.9,104.3,114.8,101.5,101.7,202.8,207.8,215.5,233.0,101.6,101.5,104.0,103.4,103.7,104.3,102.7,102.2,103.5,103.8,112.8,111.7,111.2,111.5,114.7,102.8,102.5,104.7,111.3,108.2,109.2,111.1,110.4,113.6,109.0,101.7,101.6,101.8,102.0,105.6,110.8,106.1,105.7,113.9,115.1,115.5,116.1,116.9,113.5,118.6,112.5,111.4,111.0,105.6,114.7,115.4,115.3,128.1,131.6,117.0,117.4,112.1,109.3,109.5,109.5,109.3,129.3,111.5,110.3,126.2,126.1,125.3,131.6,118.3,114.5,111.6,111.0,110.9,109.2,109.7,111.6,89.8,95.1,97.7,104.5,112.8,114.1,104.3,103.8,103.3,103.3,114.9,138.8,136.1,134.1,134.5,110.2,111.2, ...

# %% [markdown]
# ### https://realpython.com/python-dash/

# %%
def update_line_plot(year):
    filtered_df = df_eu_conuntries_new[df_eu_conuntries_new['Year'] == year]

    fig = px.line(
        filtered_df,
        x='Quarter',
        y='OBS_VALUE',
        color='geo_3',
        title='Changing OBS_VALUE by Quarter',
        labels={'Quarter': 'Quarter', 'OBS_VALUE': 'OBS_VALUE'}
    )

    fig.show()

# Create dropdown widget for the year filter
year_dropdown = widgets.Dropdown(
    options=df_eu_conuntries_new['Year'].unique(),
    value=df_eu_conuntries_new['Year'].min(),
    description='Year:'
)

# Define the function to handle the widget value change
def on_value_change(change):
    update_line_plot(year=year_dropdown.value)

# Attach the on_value_change function to the widget event
year_dropdown.observe(on_value_change, names='value')

# Display the dropdown widget
display(year_dropdown)

# Display the initial line plot
update_line_plot(year=year_dropdown.value)
